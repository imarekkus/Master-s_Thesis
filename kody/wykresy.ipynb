# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#from plotnine import *

# %% [markdown]
# # Wykres 1

# %%
# Importing file

fig_1 = pd.read_csv("https://raw.githubusercontent.com/imarekkus/Master-s_Thesis/main/dane/Wstep/Scopus-1656-Analyze-Year.csv", sep=';')
fig_1
# Out:
#    Year; Documents
# 0       2022;"217"
# 1       2021;"184"
# 2       2020;"126"
# 3       2019;"163"
# 4       2018;"134"
# 5       2017;"103"
# 6        2016;"98"
# 7        2015;"72"
# 8        2014;"69"
# 9        2013;"58"
# 10       2012;"73"
# 11       2011;"55"
# 12       2010;"52"
# 13       2009;"45"
# 14       2008;"41"
# 15       2007;"28"
# 16       2006;"25"
# 17       2005;"18"
# 18       2004;"13"
# 19        2003;"5"
# 20       2002;"12"
# 21        2001;"7"
# 22        2000;"3"
# 23        1999;"7"
# 24        1998;"6"
# 25        1997;"1"
# 26       1996;"11"
# 27        1995;"7"
# 28       1994;"10"
# 29        1993;"4"
# 30        1992;"2"
# 31        1990;"1"
# 32        1989;"1"
# 33        1986;"1"
# 34        1985;"2"
# 35        1984;"1"
# 36        1983;"1"

# %%
# Cleaning data

# Getting rid off "" in second column
fig_1["Year; Documents"] = fig_1["Year; Documents"].str.replace('"',"")

# Splitting columns into two
fig_1[['Year', 'Documents']] =  fig_1['Year; Documents'].str.split(';', expand=True)

# Dropping useless column
fig_1 = fig_1.drop(['Year; Documents'], axis=1)

# Order years
fig_1 = fig_1.sort_values(by=['Year'])

# %%
# Checking types of data
fig_1.dtypes
# Out:
# Year         object
# Documents    object
# dtype: object

# %%
# Changing types of data in columns
fig_1['Documents'] = pd.to_numeric(fig_1['Documents'])
fig_1['Year'] = pd.to_datetime(fig_1['Year'], format='%Y').dt.year

# %%
fig_1
# Out:
#     Year  Documents
# 36  1983          1
# 35  1984          1
# 34  1985          2
# 33  1986          1
# 32  1989          1
# 31  1990          1
# 30  1992          2
# 29  1993          4
# 28  1994         10
# 27  1995          7
# 26  1996         11
# 25  1997          1
# 24  1998          6
# 23  1999          7
# 22  2000          3
# 21  2001          7
# 20  2002         12
# 19  2003          5
# 18  2004         13
# 17  2005         18
# 16  2006         25
# 15  2007         28
# 14  2008         41
# 13  2009         45
# 12  2010         52
# 11  2011         55
# 10  2012         73
# 9   2013         58
# 8   2014         69
# 7   2015         72
# 6   2016         98
# 5   2017        103
# 4   2018        134
# 3   2019        163
# 2   2020        126
# 1   2021        184
# 0   2022        217

# %%
# Plotting figure
plt.figure(figsize=(13,6))
plt.style.use('seaborn')
plt.plot(fig_1['Year'], fig_1['Documents'], '-o')
plt.xlabel('Rok')
plt.ylabel('Liczba dokumentów')
plt.show()
# Out:
# C:\temp2\ipykernel_23964\1551366668.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# # Wykres 2

# %%
# Importing file

fig_2 = pd.read_csv("https://raw.githubusercontent.com/imarekkus/Master-s_Thesis/main/dane/Wstep/Scopus-305-Analyze-Year.csv", sep=';')
fig_2
# Out:
#    Year; Documents
# 0        2022;"70"
# 1        2021;"43"
# 2        2020;"45"
# 3        2019;"48"
# 4        2018;"40"
# 5        2017;"24"
# 6        2016;"21"
# 7         2015;"5"
# 8         2014;"1"
# 9         2013;"3"
# 10        2012;"3"
# 11        2011;"2"

# %%
# Cleaning data

# Getting rid off "" in second column
fig_2["Year; Documents"] = fig_2["Year; Documents"].str.replace('"',"")

# Splitting columns into two
fig_2[['Year', 'Documents']] =  fig_2['Year; Documents'].str.split(';', expand=True)

# Dropping useless column
fig_2 = fig_2.drop(['Year; Documents'], axis=1)

# Order years
fig_2 = fig_2.sort_values(by=['Year'])

# Changing types of data in columns
fig_2['Documents'] = pd.to_numeric(fig_2['Documents'])
fig_2['Year'] = pd.to_datetime(fig_2['Year'], format='%Y').dt.year

# %%
# Plotting figure
plt.figure(figsize=(13,6))
plt.style.use('seaborn')
plt.plot(fig_2['Year'], fig_2['Documents'], '-o')
plt.xlabel('Rok')
plt.ylabel('Liczba dokumentów')
plt.show()
# Out:
# C:\temp2\ipykernel_23964\912114915.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# # Wykres 3

# %%
# Importing file

fig_3 = pd.read_csv("https://raw.githubusercontent.com/imarekkus/Master-s_Thesis/main/tabele/Porownanie%20modeli.csv", sep=';')
fig_3
# Out:
#                                                 Model  Acc train  Acc test  \
# 0                                  ANN 2 dense layers      0.057     0.059
# 1                                  ANN 4 dense layers      0.058     0.059
# 2                                  CNN 1 conv 4 dense      0.058     0.059
# 3                                  CNN 1 conv 1 dense      0.991     0.862
# 4                       CNN 1 conv 1 max pool 1 dense      0.995     0.864
# 5             CNN 1 conv 1 max pool 1 dropout 1 dense      0.973     0.880
# 6             CNN 2 conv 1 max pool 1 dropout 1 dense      0.987     0.906
# 7             CNN 2 conv 2 max pool 2 dropout 1 dense      0.974     0.938
# 8             CNN 2 conv 2 max pool 3 dropout 2 dense      0.950     0.954
# 9   CNN 2 conv 2 max pool 3 dropout 2 dense batchnorm      0.996     0.971
# 10  CNN 3 conv 2 max pool 3 dropout 2 dense batchnorm      0.999     0.964
# ...

# %%
# Plotting figure
plt.figure(figsize=(20,6))
plt.style.use('seaborn')
plt.plot(fig_3['Model'], fig_3['Acc test'], '-o', color='lightblue')
plt.plot(fig_3['Model'], fig_3['Acc train'], '-o', color='grey')
plt.xticks(rotation = 90)
plt.xlabel('Model')
plt.ylabel('Trafność')
plt.show()
# Out:
# C:\temp2\ipykernel_22360\3630769370.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
